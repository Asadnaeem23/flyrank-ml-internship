# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/Asadnaeem23/flyrank-ml-internship.git
# %cd flyrank-ml-internship
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 99, done.
# remote: Counting objects: 100% (99/99), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 99 (delta 19), reused 77 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (99/99), 1.84 MiB | 11.78 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# /content/flyrank-ml-internship/flyrank-ml-internship

# %%
import os
print(os.getcwd())
print(os.listdir("."))
# Out:
# /content/flyrank-ml-internship/flyrank-ml-internship
# ['data', 'GUIDE.md', 'notebooks', 'submission', 'skills', 'DATA_USE.md', '.github', '.git', 'scripts', 'SETUP.md', 'requirements.txt', 'CLAUDE.md', 'outputs', 'LICENSE', 'README.md', 'docs', 'AGENTS.md', '.gitignore', 'work']

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(df.shape)
df.head()
# Out:
# (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## My Lane
#
# I chose the **Refresh / Content Opportunity Scoring** lane.
#
# The goal of this lane is to identify pages that should be prioritized for content refresh based on observable search and content signals. I chose this lane because reviewing every page manually is difficult, especially for large websites. A ranked list of pages can help content teams focus on the pages most likely to benefit from updates, making the review process more efficient.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## The Question
#
# **Decision:** Which content pages should be refreshed first?
#
# **Action:** An SEO or content manager reviews and updates the highest-priority pages.
#
# **Cost of a wrong recommendation:** If a page is incorrectly recommended, time and resources may be wasted. If an important page is missed, traffic and business opportunities may continue to decline.
#
# Machine learning can support this decision by ranking pages using measurable content and search signals instead of relying only on manual review.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick Look at the Data
#
# The starter dataset contains **30,000 content pages** from **32 anonymized clients**.
#
# Most pages are **keyword articles (27,207)**, followed by **feedly articles (2,096)** and **comparison articles (697)**.
#
# The trend distribution shows that **16,262 pages are classified as "down"**, compared with **5,962 stable** and **4,388 up** pages. This suggests there are many pages that could potentially benefit from review or refresh, making this lane a useful decision-support problem.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Total pages:", len(df))
print("Unique clients:", df["client_id"].nunique())
print("Content types:")
print(df["content_type"].value_counts())

print("\nTrend distribution:")
print(df["trend_direction"].value_counts())
# Out:
# Total pages: 30000
# Unique clients: 32
# Content types:
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64
#
# Trend distribution:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Careful Words
#
# This work is intended to support content refresh decisions using observable patterns in the available data. Any findings should be interpreted as measured associations or directional evidence rather than proof of cause and effect.
#
# This project does not predict Google's algorithm or guarantee future rankings. Instead, it provides decision support that can help prioritize pages for manual review.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
